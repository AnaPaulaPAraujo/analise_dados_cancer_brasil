# %%
import pandas as pd
import numpy as np

# %%
# dataset_1 = pd.read_csv('INCA_2005_2011.csv', sep = ';', encoding = 'latin-1', low_memory = False, index_col = 0)
# dataset_2 = pd.read_csv('INCA_2012_2019.csv', sep = ';', encoding = 'latin-1', low_memory = False, index_col = 0)

# %%
# dataset_1.head(7)
# Out:
#                              Nome do RCBP       Sexo Data de Nascimento  \
# Código do Paciente
# 672054.0            RCBP CAMPINAS-UNICAMP  MASCULINO         16/03/1975
# 673745.0            RCBP CAMPINAS-UNICAMP  MASCULINO         03/07/1934
# 676350.0            RCBP CAMPINAS-UNICAMP  MASCULINO         18/11/1933
# 679877.0            RCBP CAMPINAS-UNICAMP   FEMININO         30/11/1947
# 676553.0            RCBP CAMPINAS-UNICAMP  MASCULINO         30/01/1953
# 679345.0            RCBP CAMPINAS-UNICAMP  MASCULINO         09/10/1930
# 682806.0            RCBP CAMPINAS-UNICAMP  MASCULINO         02/05/1946
#
#                     Idade Raca/Cor Nacionalidade Naturalidade Estado  \
# Código do Paciente
# 672054.0             30.0   BRANCO        BRASIL           SÃO PAULO
# 673745.0             71.0   BRANCO        BRASIL           SÃO PAULO
# 676350.0             71.0   BRANCO        BRASIL           SÃO PAULO
# 679877.0             57.0    PARDA        BRASIL             ALAGOAS
# ...

# %%
# data_union1 = pd.merge(dataset_1,dataset_2, how = 'outer')

# %%
# data_union1.columns
# Out:
# Index(['Nome do RCBP', 'Sexo', 'Data de Nascimento', 'Idade', 'Raca/Cor',
#        'Nacionalidade', 'Naturalidade Estado', 'Naturalidade',
#        'Grau de Instrução', 'Estado Civil', 'Código Profissão',
#        'Nome Profissão', 'Estado Endereço', 'Cidade Endereço',
#        'Descrição da Topografia', 'Código da Topografia',
#        'Descrição da Morfologia', 'Código da Morfologia',
#        'Descrição da Doenca', 'Código da Doenca',
#        'Descrição da Doenca Infantil', 'Código da Doenca Infantil',
#        'Descrição da Doenca Adulto Jovem', 'Código da Doenca Adulto Jovem',
#        'Indicador de Caso Raro', 'Meio de Diagnostico', 'Extensão',
#        'Lateralidade', 'Estadiamento', 'TNM', 'Status Vital', 'Tipo do Obito',
#        'Data do Óbito', 'Data de Último Contato', 'Data de Diagnostico',
#        'Metástase à distância', 'Unnamed: 37'],
#       dtype='object')

# %%
# data_union2 = data_union1[['Sexo', 'Idade', 'Raca/Cor', 'Estado Endereço', 'Data de Diagnostico']]

# %%
# data_union2.head()
# Out:
#         Sexo  Idade Raca/Cor Estado Endereço Data de Diagnostico
# 0  MASCULINO   30.0   BRANCO       SÃO PAULO          07/10/2005
# 1  MASCULINO   71.0   BRANCO       SÃO PAULO          21/10/2005
# 2  MASCULINO   71.0   BRANCO       SÃO PAULO          06/11/2005
# 3   FEMININO   57.0    PARDA       SÃO PAULO          15/05/2005
# 4  MASCULINO   52.0   BRANCO       SÃO PAULO          24/02/2005

# %%
# data_union3 = data_union2.rename(columns = {'Sexo':'sexo', 'Idade':'idade', 'Raca/Cor': 'raca_cor','Estado Endereço': 'estado', 'Data de Diagnostico': 'data'})
# data_union3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1305823 entries, 0 to 1305822
# Data columns (total 5 columns):
#  #   Column    Non-Null Count    Dtype
# ---  ------    --------------    -----
#  0   sexo      1305823 non-null  object
#  1   idade     1242934 non-null  float64
#  2   raca_cor  1305823 non-null  object
#  3   estado    1263373 non-null  object
#  4   data      1263728 non-null  object
# dtypes: float64(1), object(4)
# memory usage: 59.8+ MB

# %%
# data_union3.head()
# Out:
#         sexo  idade raca_cor     estado        data
# 0  MASCULINO   30.0   BRANCO  SÃO PAULO  07/10/2005
# 1  MASCULINO   71.0   BRANCO  SÃO PAULO  21/10/2005
# 2  MASCULINO   71.0   BRANCO  SÃO PAULO  06/11/2005
# 3   FEMININO   57.0    PARDA  SÃO PAULO  15/05/2005
# 4  MASCULINO   52.0   BRANCO  SÃO PAULO  24/02/2005

# %%
# data_union3.to_csv("data_cancer_2005_2019.csv")
