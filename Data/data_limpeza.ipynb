# %% [markdown]
# # 1. Importando bibliotecas para utilização no projeto

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 2. Importando e analisando os dados coletados
#
# Dados sobre os casos de câncer no Brasil (2012 - 2019) disponíveis no site do INCA (Instituto Nacional de Câncer) <https://www.inca.gov.br/>.

# %%
#dataset = pd.read_csv('NAO_IDENT_null_1988-2019_2012_2019_76542.csv', sep = ';', encoding = 'latin-1', low_memory = False, index_col = 0)

# %%
#dataset.head(10)
# Out:
#                     Nome do RCBP       Sexo Data de Nascimento  Idade  \
# Código do Paciente
# NaN                 RCBP GOIÂNIA   FEMININO         11/03/1943   68.0
# NaN                 RCBP GOIÂNIA   FEMININO         10/04/1966   46.0
# NaN                 RCBP GOIÂNIA   FEMININO         05/05/1924   88.0
# NaN                 RCBP GOIÂNIA   FEMININO         10/03/1947   65.0
# NaN                 RCBP GOIÂNIA   FEMININO         30/01/1948   63.0
# NaN                 RCBP GOIÂNIA   FEMININO         11/09/1946   66.0
# NaN                 RCBP GOIÂNIA   FEMININO         13/10/1948   63.0
# NaN                 RCBP GOIÂNIA   FEMININO         13/10/1948   63.0
# NaN                 RCBP GOIÂNIA  MASCULINO         17/02/1929   83.0
# NaN                 RCBP GOIÂNIA  MASCULINO         06/02/1950   62.0
#
#                           Raca/Cor Nacionalidade Naturalidade Estado  \
# Código do Paciente
# NaN                         BRANCO           NaN                 NaN
# ...

# %% [markdown]
# ### Arquivo de muito grande e com informações desnecessárias para o projeto!

# %%
#dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 496661 entries, nan to 1398299.0
# Data columns (total 37 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   Nome do RCBP                      496661 non-null  object
#  1   Sexo                              496661 non-null  object
#  2   Data de Nascimento                337038 non-null  object
#  3   Idade                             482006 non-null  float64
#  4   Raca/Cor                          496661 non-null  object
#  5   Nacionalidade                     329322 non-null  object
#  6   Naturalidade Estado               329819 non-null  object
#  7   Naturalidade                      215906 non-null  object
#  8   Grau de Instrução                 339909 non-null  object
#  9   Estado Civil                      339908 non-null  object
#  10  Código Profissão                  464021 non-null  float64
# ...

# %% [markdown]
# # 3. Selecionando os dados que serão armazenados em um novo arquivo .csv
#
# Como o arquivo original excede o tamanho suportado pelo GitHub e também possui diversas informação que não serão usadas no projeto, então há a necessidade de escolher os dados que farão parte de um novo dataframe e de um novo .csv mais compacto e objetivo.

# %%
#dataset.columns
# Out:
# Index(['Nome do RCBP', 'Sexo', 'Data de Nascimento', 'Idade', 'Raca/Cor',
#        'Nacionalidade', 'Naturalidade Estado', 'Naturalidade',
#        'Grau de Instrução', 'Estado Civil', 'Código Profissão',
#        'Nome Profissão', 'Estado Endereço', 'Cidade Endereço',
#        'Descrição da Topografia', 'Código da Topografia',
#        'Descrição da Morfologia', 'Código da Morfologia',
#        'Descrição da Doenca', 'Código da Doenca',
#        'Descrição da Doenca Infantil', 'Código da Doenca Infantil',
#        'Descrição da Doenca Adulto Jovem', 'Código da Doenca Adulto Jovem',
#        'Indicador de Caso Raro', 'Meio de Diagnostico', 'Extensão',
#        'Lateralidade', 'Estadiamento', 'TNM', 'Status Vital', 'Tipo do Obito',
#        'Data do Óbito', 'Data de Último Contato', 'Data de Diagnostico',
#        'Metástase à distância', 'Unnamed: 37'],
#       dtype='object')

# %%
#data_selection = dataset[['Sexo', 'Idade', 'Raca/Cor', 'Estado Endereço', 'Código da Doenca', 'Código da Doenca Infantil', 'Código da Doenca Adulto Jovem']]
#data_selection
# Out:
#                          Sexo  Idade        Raca/Cor Estado Endereço  \
# Código do Paciente
# NaN                  FEMININO   68.0          BRANCO           GOIAS
# NaN                  FEMININO   46.0  SEM INFORMAÇÃO           GOIAS
# NaN                  FEMININO   88.0          BRANCO           GOIAS
# NaN                  FEMININO   65.0          BRANCO           GOIAS
# NaN                  FEMININO   63.0          BRANCO           GOIAS
# ...                       ...    ...             ...             ...
# 1331797.0           MASCULINO   68.0           PARDA        RONDONIA
# 1331551.0            FEMININO   24.0           PARDA        RONDONIA
# 1331058.0            FEMININO   56.0          BRANCO        RONDONIA
# 1331001.0           MASCULINO   40.0           PARDA        RONDONIA
# 1398299.0            FEMININO   61.0          BRANCO        RONDONIA
#
#                    Código da Doenca Código da Doenca Infantil  \
# Código do Paciente
# ...

# %%
#data_selection.to_csv("dados_filtrados.csv")
